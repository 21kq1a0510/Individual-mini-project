# %% [markdown]
# ### Individual Mini Project

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
penguin=pd.read_csv("penguins_size.csv")
penguin
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %% [markdown]
# ### 1.Data Understanding

# %%
penguin.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# ### 2.Initial Check Up

# %%
penguin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguin.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# ### 3.Asking Questions to the Data

# %%
###1.Which species penguin is highest among other penguins
###2.Species with body mass and flipper length
###3.Which species is living in Torgersen	island
###4.Who many male and female penguins in Dream island
###5.Which island has highest flipper_length penguins
###6.How many species are living in the Biscoe island
###7.Which species have highest body_mass
###8.Which species has highest culmen_length_mm 
###9.Island wisePenguins body mass in grams
###10.Gentoo & Chinstrap are belongs to which island
###11.Culmen depth of species

# %% [markdown]
# ### Univariant Analysis

# %%
penguin['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguin['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
penguin['species'].value_counts(normalize=True)*100
# Out:
# species
# Adelie       44.186047
# Gentoo       36.046512
# Chinstrap    19.767442
# Name: proportion, dtype: float64

# %% [markdown]
# ### Bivarient & Multi-variant Analysis

# %%
###1.Which species penguin has highest among other penguins
sns.countplot(penguin,x='species',hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
###2.Species with body mass and flipper length
sns.lineplot(penguin,x='body_mass_g',y='flipper_length_mm',hue='species')
# Out:
# C:\Users\sindhu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sindhu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
###3.Which species is living in Torgersen island
iland=penguin[penguin['island']=='Torgersen']
sns.countplot(iland,x='species')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
###4.Who many male and female penguins in Dream island
a=penguin[penguin['island']=='Dream']
sns.countplot(a,x='sex',hue='species')
#61 female and 63 male
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
###5.Which island has highest flipper_length penguins
sns.boxplot(penguin,x='island',y='flipper_length_mm',hue="species")
# Out:
# <Axes: xlabel='island', ylabel='flipper_length_mm'>

# %%
###6.How many species are living in the Biscoe island
b=penguin[penguin['island']=='Biscoe']
sns.countplot(b,x='species')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
###7.Which species have highest body_mass
sns.violinplot(penguin,x='species',y='body_mass_g')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
###8.Which species has highest culmen_length_mm 
sns.barplot(penguin,x='species',y='culmen_length_mm',estimator=np.max,hue='island')
# Out:
# <Axes: xlabel='species', ylabel='culmen_length_mm'>

# %%
###9.Island wise Penguins body mass in grams
sns.kdeplot(penguin,x='body_mass_g',hue='island')
# Out:
# C:\Users\sindhu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
###10.Gentoo & Chinstrap are belongs to which island
a=penguin[penguin['species'].isin(['Gentoo','Chinstrap'])]
sns.countplot(a,x='island',hue='species')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
###11.Culmen depth of species
sns.violinplot(penguin,x='species',y='culmen_depth_mm',hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='culmen_depth_mm'>

# %%
sns.countplot(penguin,x='island',hue='species')
#gentoo is live only in biscoe
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# ### Insights

# %%
#1.Adelie species is highest count among all other species, there are living in three islands.
#2.Biscoe island have more count of species with 168.
#3.Biscoe island have two species only i.e. Adelie and Gentoo.
#4.Chinstrap species is very less in count with 68 penguins.
#5.Dream island have two species i.e. Adelie and Chinstrap.
#6.Torgersen island having only one species i.e. Adelie.
#7.Gentoo species has high in body_mass_g, flipper_lenght_mm and culmen_lenght_mm but low in culmen_depth_mm.
#8.Gentoo species is living only in Biscoe island.
#9.Adelie species has more culmen_depth_mm.
#10.Dream island have 61 female and 63 male total is 124.
#11.Adelie specise has less body_mass and flipper_length_mm.
#12.Gentoo species has more body_mass and flipper_length_mm.
#13.Dream island species are recorded with high body_mass.
#14.Male gender penguins is more than females.
#15.Chinstrap species is living in Dream island only.
